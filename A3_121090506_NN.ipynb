# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

train_set = pd.read_csv(r"C:\Users\谭兆宏\Desktop\train.csv")
test_set = pd.read_csv(r"C:\Users\谭兆宏\Desktop\test.csv")

title_list = []
for i in range(784):
    title_list.append('pixel'+str(i))
# split the data into x and y
X_train = train_set.drop('Category', axis=1)
X_train = X_train.drop('Id', axis=1)
X_train.columns = title_list
y_train = train_set['Category']
X_test = test_set.drop('label', axis=1)
X_test.columns = title_list
y_test = test_set['label']
y_test.columns = 'Category'

# %%
number_of_hidden_layers, number_of_hidden_nodes, list_of_optimizers = [1, 2, 3], [50, 200, 784], ['adam', 'sgd']
learning_rate = [0.001, 0.01]
# Create and train the MLPClassifier
for layers in number_of_hidden_layers:
    for nodes in number_of_hidden_nodes:
        for optimizer in list_of_optimizers:
            for rate in learning_rate:
                hidden_layer_size = tuple([nodes]*layers)
                mlp = MLPClassifier(hidden_layer_sizes=hidden_layer_size, solver=optimizer,
                                    max_iter=1000, learning_rate_init=rate)
                mlp.fit(X_train, y_train)
                y_predict = mlp.predict(X_test)
                accuracy = accuracy_score(y_test, y_predict)
                print('The current hidden layer is:', layers,
                      'The current number of hidden nodes is:', nodes, '\n',
                      'The current optimize is:', optimizer,
                      'The current learning rate is:', rate)
                print('The current accuracy is:', accuracy, '\n')
# Out:
# The current hidden layer is: 1 The current number of hidden nodes is: 50
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8566
#
# The current hidden layer is: 1 The current number of hidden nodes is: 50
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.2567
#
# The current hidden layer is: 1 The current number of hidden nodes is: 50
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.6041
#
# The current hidden layer is: 1 The current number of hidden nodes is: 50
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 1 The current number of hidden nodes is: 200
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8692
#
# The current hidden layer is: 1 The current number of hidden nodes is: 200
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.5723
#
# The current hidden layer is: 1 The current number of hidden nodes is: 200
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.8441
#
# The current hidden layer is: 1 The current number of hidden nodes is: 200
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1165
#
# The current hidden layer is: 1 The current number of hidden nodes is: 784
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8654
#
# The current hidden layer is: 1 The current number of hidden nodes is: 784
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.592
#
# The current hidden layer is: 1 The current number of hidden nodes is: 784
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.8642
#
# The current hidden layer is: 1 The current number of hidden nodes is: 784
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.115
#
# The current hidden layer is: 2 The current number of hidden nodes is: 50
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8716
#
# The current hidden layer is: 2 The current number of hidden nodes is: 50
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.8279
#
# The current hidden layer is: 2 The current number of hidden nodes is: 50
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.1
#
# The current hidden layer is: 2 The current number of hidden nodes is: 50
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 2 The current number of hidden nodes is: 200
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8775
#
# The current hidden layer is: 2 The current number of hidden nodes is: 200
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.596
#
# The current hidden layer is: 2 The current number of hidden nodes is: 200
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.1
#
# The current hidden layer is: 2 The current number of hidden nodes is: 200
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 2 The current number of hidden nodes is: 784
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8902
#
# The current hidden layer is: 2 The current number of hidden nodes is: 784
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 2 The current number of hidden nodes is: 784
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.1
#
# The current hidden layer is: 2 The current number of hidden nodes is: 784
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 3 The current number of hidden nodes is: 50
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.875
#
# The current hidden layer is: 3 The current number of hidden nodes is: 50
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.811
#
# The current hidden layer is: 3 The current number of hidden nodes is: 50
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.1
#
# The current hidden layer is: 3 The current number of hidden nodes is: 50
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 3 The current number of hidden nodes is: 200
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8898
#
# The current hidden layer is: 3 The current number of hidden nodes is: 200
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.7884
#
# The current hidden layer is: 3 The current number of hidden nodes is: 200
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.1
#
# The current hidden layer is: 3 The current number of hidden nodes is: 200
#  The current optimize is: sgd The current learning rate is: 0.01
# The current accuracy is: 0.1
#
# The current hidden layer is: 3 The current number of hidden nodes is: 784
#  The current optimize is: adam The current learning rate is: 0.001
# The current accuracy is: 0.8984
#
# The current hidden layer is: 3 The current number of hidden nodes is: 784
#  The current optimize is: adam The current learning rate is: 0.01
# The current accuracy is: 0.7749
#
# The current hidden layer is: 3 The current number of hidden nodes is: 784
#  The current optimize is: sgd The current learning rate is: 0.001
# The current accuracy is: 0.5393
# D:\python310\lib\site-packages\sklearn\utils\extmath.py:189: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# D:\python310\lib\site-packages\sklearn\utils\extmath.py:189: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
